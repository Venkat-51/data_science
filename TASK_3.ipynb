# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkat-51/data_science/blob/main/TASK_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pymupdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 34.2 MB/s eta 0:00:00
# ...

# %%
import fitz  # PyMuPDF

# Example usage
pdf_text_pymupdf = read_pdf_with_pymupdf("/content/drive/MyDrive/Data science task/Test-Int-Package-Data.pdf")

# Print or do something with the extracted text
print(pdf_text_pymupdf)
# Out:
# Hotel ID
# Type
# Location
# Destination
# Property
# Room Category
# CUR
# Totel Rooms
# CP
# 2N
# HONEYMOON
# PACKAGE IDR
# 1N-INR Price
# 2N  -
# Honeymoon
# Package to
# INR
# 2N Cost
# Unique Room
# ID
# Package-ID-1
# SN-01
# Package ID-2
# SN-02
# Room Primary
# Primary Meal
# PKH - O3
# PKH - O4
# Package Title
# Tariff Start
# Date - 1
# Tariff End Date
# - 1
# Tariff Start
# Date - 2
# Tariff End Date
# - 2
# Tariff Start
# Date - 3
# Tariff End Date
# - 3
# I-BAL-UBUD-AKS-001
# International
# Bali
# Ubud
# Aksari Resort Ubud
# Royal One Bedroom River View Villa with Private Pool
# IDR
# 2
# 3,200,000
# 11,800,000
# 16766
# 61826
# 33533
# 24890
# BA-HO-12-NO-002
# 2
# 3
# 0
# CP
# `
# 20-Dec-2023
# I-BAL-UBUD-AKS-001
# International
# Bali
# Ubud
# Aksari Resort Ubud
# Royal One Bedroom Villa with Private Pool
# IDR
# 4
# 3,200,010
# 10,800,000
# 16766
# 56586
# 33533
# 24891
# BA-HO-12-NO-003
# 3
# 3
# 1
# CP
# 16-Sep-2023
# 20-Dec-2023
# I-BAL-UBUD-AKS-001
# ...

# %%
pip install tabula-py pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 31.2 MB/s eta 0:00:00
# ...

# %%
import tabula

# Replace 'your_file.pdf' with the path to your PDF file
pdf_file_path = '/content/drive/MyDrive/Data science task/Test-Int-Package-Data.pdf'

# Read PDF into DataFrame
df = tabula.read_pdf("/content/drive/MyDrive/Data science task/Test-Int-Package-Data.pdf", pages='all')

# Print the extracted data
print(df)
# Out:
# WARNING:tabula.backend:Error importing jpype dependencies. Fallback to subprocess.
# WARNING:tabula.backend:No module named 'jpype'
# [              Hotel ID           Type Location Destination  \
# 0   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 1   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 2   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 3   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 4   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# ..                 ...            ...      ...         ...
# 78                 NaN            NaN      NaN         NaN
# 79                 NaN            NaN      NaN         NaN
# 80                 NaN            NaN      NaN         NaN
# 81                 NaN            NaN      NaN         NaN
# 82                 NaN            NaN      NaN         NaN
#
#               Property                                         Unnamed: 0  \
# ...
